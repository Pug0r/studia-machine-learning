# %% [markdown]
# # Exercises
#
# There are three exercises in this notebook:
#
# 1. Use the cross-validation method to test the linear regression with different $\alpha$ values, at least three.
# 2. Implement a SGD method that will train the Lasso regression for 10 epochs.
# 3. Extend the Fisher's classifier to work with two features. Use the class as the $y$.

# %% [markdown]
# ## 1. Cross-validation linear regression
#
# You need to change the variable ``alpha`` to be a list of alphas. Next do a loop and finally compare the results.

# %%
# import sys

# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install matplotlib

# !{sys.executable} -m pip install scikit-learn
# !{sys.executable} -m pip install scipy

# %%
import numpy as np
import pandas as pd
x = np.array([188, 181, 197, 168, 167, 187, 178, 194, 140, 176, 168, 192, 173, 142, 176]).reshape(-1, 1).reshape(15,1)
y = np.array([141, 106, 149, 59, 79, 136, 65, 136, 52, 87, 115, 140, 82, 69, 121]).reshape(-1, 1).reshape(15,1)

x = np.asmatrix(np.c_[np.ones((15,1)),x])

I = np.identity(2)
alphas = np.arange(0, 1, 0.05)
results = []

for alpha in alphas:
    w = np.linalg.inv(x.T*x + alpha * I)*x.T*y
    y_pred = x * w
    mse = np.mean(np.square(y - y_pred))
    w_flat = np.asarray(w).flatten()
    results.append([w_flat[0], w_flat[1], mse])

comparison_df = pd.DataFrame(results, columns=['Intercept', 'Slope', 'MSE'], index=alphas)
print(comparison_df)
# Out:
#        Intercept     Slope         MSE
# 0.00 -180.924018  1.618142  372.331292
# 0.05 -130.228040  1.331150  394.339358
# 0.10 -101.723971  1.169788  426.045077
# 0.15  -83.456832  1.066376  453.680201
# 0.20  -70.751422  0.994451  476.271132
# 0.25  -61.403292  0.941530  494.658010
# 0.30  -54.237043  0.900962  509.766754
# 0.35  -48.568621  0.868873  522.340594
# 0.40  -43.972861  0.842856  532.938963
# 0.45  -40.171607  0.821337  541.978441
# 0.50  -36.975220  0.803242  549.771060
# 0.55  -34.249969  0.787814  556.553270
# 0.60  -31.898837  0.774504  562.506628
# 0.65  -29.849736  0.762904  567.772419
# 0.70  -28.047977  0.752704  572.461999
# 0.75  -26.451327  0.743665  576.664193
# 0.80  -25.026648  0.735600  580.450640
# 0.85  -23.747575  0.728359  583.879714
# 0.90  -22.592872  0.721822  586.999429
# 0.95  -21.545240  0.715891  589.849623

# %% [markdown]
# ## 2. Implement based on the Ridge regression example, the Lasso regression.
#
# Please implement the SGD method and compare the results with the sklearn Lasso regression results.

# %%
def sgd(X, y, alpha, lr=0.001, epochs=1000):
    n = X.shape[1]
    w = np.zeros(n) #  strating weight are zeros
    
    for _ in range(epochs):
        for i in range(len(y)):  
            y_hat = np.dot(X[i], w)
            
            error = y_hat - y[i]
            
            gradient = X[i] * error

            l1_penalty = alpha * np.sign(w)
            l1_penalty[0] = 0  # intercept
            
            w = w - lr * (gradient + l1_penalty)
            
    return w

# %%
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler

x = np.array([188, 181, 197, 168, 167, 187, 178, 194, 140, 176, 168, 192, 173, 142, 176]).reshape(-1, 1).reshape(15,1)
y = np.array([141, 106, 149, 59, 79, 136, 65, 136, 52, 87, 115, 140, 82, 69, 121]).reshape(-1, 1).reshape(15,1)
alpha = 0.1 

# need to scale data!! otherwise you get nans everywhere
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
x = np.c_[np.ones(len(x_scaled)), x_scaled]

lasso_regressor = Lasso(alpha=alpha)
lasso_regressor.fit(np.asarray(x), np.asarray(y))
print(lasso_regressor.coef_, lasso_regressor.intercept_)

w_sgd = sgd(np.asarray(x), y.flatten(), alpha)
print("SGD Coefficients:", w_sgd)
# Out:
# [ 0.         26.23725365] [102.46666667]
# SGD Coefficients: [102.49094483  26.1915708 ]

# %% [markdown]
# ## 3. Extend the Fisher's classifier
#
# Please extend the targets of the ``iris_data`` variable and use it as the $y$.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

iris_data = load_iris()
iris_df = pd.DataFrame(iris_data.data,columns=iris_data.feature_names)
iris_df['target'] = iris_data.target
iris_df.head()

x = iris_df['sepal width (cm)'].values # change here
y = iris_df['target'].values # change here

dataset_size = np.size(x)

mean_x, mean_y = np.mean(x), np.mean(y)

SS_xy = np.sum(y * x) - dataset_size * mean_y * mean_x
SS_xx = np.sum(x * x) - dataset_size * mean_x * mean_x

a = SS_xy / SS_xx
b = mean_y - a * mean_x


y_pred = a * x + b
df = pd.DataFrame(y_pred)
df
# Out:
#             0
# 0    0.645015
# 1    1.045977
# 2    0.885592
# 3    0.965785
# 4    0.564823
# ..        ...
# 145  1.045977
# 146  1.446939
# 147  1.045977
# 148  0.725207
# 149  1.045977
#
# [150 rows x 1 columns]
